# %%
import seaborn as sns

# %%
sns.set_theme(style="whitegrid")

# %%
# %ax = sns.barplot(x="day", y="total_bill", data=tips)
# Out:
# UsageError: Line magic function `%ax` not found.

# %%
import pandas as pd

df = pd.read_csv("ppo_benchmark.csv")

# %%
df
# Out:
#    Scenario Type                 Scenario  Average Goal Difference
# 0        Offense            Easy Crossing                     0.67
# 1        Offense            Easy Crossing                     0.75
# 2        Offense            Easy Crossing                     0.75
# 3        Offense            Hard Crossing                     0.08
# 4        Offense            Hard Crossing                     0.02
# 5        Offense            Hard Crossing                     0.01
# 6        Offense                 11 vs GK                     0.02
# 7        Offense                 11 vs GK                     0.00
# 8        Offense                 11 vs GK                     0.93
# 9        Offense   Avoid, Pass, and Shoot                     0.60
# 10       Offense   Avoid, Pass, and Shoot                     0.38
# 11       Offense   Avoid, Pass, and Shoot                     0.89
# 12       Defense                     1vs1                    -0.62
# 13       Defense                     1vs1                    -0.59
# 14       Defense                     1vs1                    -0.61
# 15       Defense    Behavior Defense 1vs1                    -0.19
# 16       Defense    Behavior Defense 1vs1                    -0.12
# 17       Defense    Behavior Defense 1vs1                    -0.14
# 18       Defense                     2vs2                    -0.38
# 19       Defense                     2vs2                    -0.11
# 20       Defense                     2vs2                    -0.16
# 21       Defense           Long Pass 2vs2                    -0.50
# 22       Defense           Long Pass 2vs2                    -0.46
# 23       Defense           Long Pass 2vs2                    -0.33
# 24       Defense  Behavior Long Pass 2vs2                    -0.18
# 25       Defense  Behavior Long Pass 2vs2                    -0.10
# 26       Defense  Behavior Long Pass 2vs2                    -0.20
# 27       Defense                     3vs3                    -0.15
# 28       Defense                     3vs3                    -0.29
# 29       Defense                     3vs3                    -0.26
# 30       Defense      Behavior 3vs3 Cross                    -0.27
# 31       Defense      Behavior 3vs3 Cross                    -0.09
# 32       Defense      Behavior 3vs3 Cross                    -0.25
# 33       Defense           GK vs Attacker                    -0.08
# 34       Defense           GK vs Attacker                    -0.02
# 35       Defense           GK vs Attacker                    -0.09
# 36       Defense       Counterattack 3vs2                    -0.44
# 37       Defense       Counterattack 3vs2                    -0.36
# 38       Defense       Counterattack 3vs2                    -0.34

# %%
from matplotlib import pyplot
import textwrap

pyplot.figure(figsize=(24, 8))
#sns.set_palette("Deep")
sns.set(font_scale=1.3)
palette = ["C0"]*4 + ["C1"]*9
#ax = sns.barplot(x="Scenario", y="Average Goal Difference", hue='Scenario Type', data=df)
ax = sns.barplot(x="Scenario", y="Average Goal Difference", data=df, palette=palette)

from matplotlib.ticker import MultipleLocator
ax.yaxis.set_major_locator(MultipleLocator(0.2))
ax.set(ylim=(-1, 1))
#for item in ax.get_xticklabels():
#    item.set_rotation(45)

ax.set_xticklabels(['\n'.join(textwrap.wrap(ticklabel.get_text(),8)) for ticklabel in ax.get_xticklabels()])

#for item in ax.get_xticklabels():
#    item.set_rotation(45)

ax.figure.savefig("benchmark.png", bbox_inches="tight")
