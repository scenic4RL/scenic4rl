# %%
import seaborn as sns

# %%
sns.set_theme(style="whitegrid")

# %%
import pandas as pd

df = pd.read_csv("testing.csv")

# %%
df
# Out:
#    Scenario Type                         Scenario Evaluation Script  \
# 0            NaN                       Empty Goal          Training
# 1            NaN                       Empty Goal          Training
# 2            NaN                       Empty Goal          Training
# 3            NaN                 Empty Goal Close          Training
# 4            NaN                 Empty Goal Close          Training
# 5            NaN                 Empty Goal Close          Training
# 6            NaN       Pass and Shoot with Keeper          Training
# 7            NaN       Pass and Shoot with Keeper          Training
# 8            NaN       Pass and Shoot with Keeper          Training
# 9            NaN                     Run to Score          Training
# 10           NaN                     Run to Score          Training
# 11           NaN                     Run to Score          Training
# 12           NaN  Run, Pass and Shoot with Keeper          Training
# 13           NaN  Run, Pass and Shoot with Keeper          Training
# 14           NaN  Run, Pass and Shoot with Keeper          Training
# 15           NaN                       Empty Goal           Testing
# 16           NaN                       Empty Goal           Testing
# 17           NaN                       Empty Goal           Testing
# 18       academy                 Empty Goal Close           Testing
# 19           NaN                 Empty Goal Close           Testing
# 20           NaN                 Empty Goal Close           Testing
# 21           NaN       Pass and Shoot with Keeper           Testing
# 22           NaN       Pass and Shoot with Keeper           Testing
# 23           NaN       Pass and Shoot with Keeper           Testing
# 24           NaN                     Run to Score           Testing
# 25           NaN                     Run to Score           Testing
# 26           NaN                     Run to Score           Testing
# 27           NaN  Run, Pass and Shoot with Keeper           Testing
# 28           NaN  Run, Pass and Shoot with Keeper           Testing
# 29           NaN  Run, Pass and Shoot with Keeper           Testing
#
#     Average Goal Difference
# 0                  0.950000
# 1                  0.930000
# 2                  0.920000
# 3                  1.000000
# 4                  1.000000
# 5                  1.000000
# 6                  0.800000
# 7                  0.850000
# 8                  0.800000
# 9                  0.950000
# 10                 0.920000
# 11                 0.900000
# 12                 0.700000
# 13                 0.710000
# 14                 0.510000
# 15                 0.550000
# 16                 0.570000
# 17                 0.570000
# 18                 0.420000
# 19                 0.090000
# 20                 0.410000
# 21                -0.022727
# 22                 0.000000
# 23                 0.045977
# 24                 0.500000
# 25                 0.329545
# 26                 0.455556
# 27                 0.000000
# 28                 0.000000
# 29                 0.000000

# %%
#df = df["Type" != "BC Policy"]

# %%
#df

# %%
from matplotlib import pyplot
import textwrap
pyplot.figure(figsize=(8, 4))
sns.set(font_scale=1.3)

ax = sns.barplot(x="Scenario", y="Average Goal Difference", hue='Evaluation Script', data=df)

from matplotlib.ticker import MultipleLocator
ax.yaxis.set_major_locator(MultipleLocator(0.2))
ax.set(ylim=(0, 1))
ax.set_xticklabels(['\n'.join(textwrap.wrap(ticklabel.get_text(),8)) for ticklabel in ax.get_xticklabels()])
pyplot.legend(loc='upper right')
ax.figure.savefig("testing.png", bbox_inches="tight")
