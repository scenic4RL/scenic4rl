# %%
import seaborn as sns

# %%
import pandas as pd

df = pd.read_csv("testing.csv")

# %%
df
# Out:
#     Scenario Type                                          Scenario  \
# 0         Academy                                        Empty Goal
# 1         Academy                                        Empty Goal
# 2         Academy                                        Empty Goal
# 3         Academy                                  Empty Goal Close
# 4         Academy                                  Empty Goal Close
# ..            ...                                               ...
# 103       Defense           Defense 3vs3 with SCENIC Cross Behavior
# 104       Defense           Defense 3vs3 with SCENIC Cross Behavior
# 105       Defense  Defender vs Opponent with SCENIC Zigzag Behavior
# 106       Defense  Defender vs Opponent with SCENIC Zigzag Behavior
# 107       Defense  Defender vs Opponent with SCENIC Zigzag Behavior
#
#     Evaluation Script  Average Goal Difference
# 0            Training                 0.950000
# 1            Training                 0.930000
# 2            Training                 0.920000
# 3            Training                 1.000000
# 4            Training                 1.000000
# ..                ...                      ...
# 103           Testing                -0.096774
# 104           Testing                 0.035714
# 105           Testing                -0.109756
# 106           Testing                -0.162791
# 107           Testing                -0.226667
#
# [108 rows x 4 columns]

# %%
#df = df["Type" != "BC Policy"]

# %%
#df

# %%
from matplotlib import pyplot
import textwrap

#sns.set_theme(style="whitegrid")
sns.set_style('white')
pyplot.figure(figsize=(24, 4))
sns.set(font_scale=1.3)

ax = sns.barplot(x="Scenario", y="Average Goal Difference", hue='Evaluation Script', data=df)

from matplotlib.ticker import MultipleLocator
ax.yaxis.set_major_locator(MultipleLocator(0.2))
ax.set(ylim=(-1, 1))
ax.set_xticklabels(['\n'.join(textwrap.wrap(ticklabel.get_text(),8)) for ticklabel in ax.get_xticklabels()])
pyplot.legend(loc='upper right')
ax.figure.savefig("testing.png", bbox_inches="tight")
