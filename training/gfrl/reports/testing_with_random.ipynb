# %%
import seaborn as sns

# %%
import pandas as pd

df = pd.read_csv("testing_with_random.csv")

# %%
df
# Out:
#     Scenario Type         Scenario Evaluation Script  Average Goal Difference
# 0         Defense             2vs2          Training                -0.303371
# 1         Defense             2vs2          Training                -0.179487
# 2         Defense             2vs2          Training                -0.136364
# 3         Defense             2vs2          Training                -0.131148
# 4         Defense             2vs2          Training                -0.126984
# ..            ...              ...               ...                      ...
# 175       Defense  GK vs Opponnent           Testing                -0.192857
# 176       Defense  GK vs Opponnent           Testing                -0.185897
# 177       Defense  GK vs Opponnent           Testing                -0.173333
# 178       Defense  GK vs Opponnent           Testing                -0.163399
# 179       Defense  GK vs Opponnent           Testing                -0.128378
#
# [180 rows x 4 columns]

# %%
from matplotlib import pyplot
import textwrap

#sns.set_theme(style="whitegrid")
sns.set_style('white')
pyplot.figure(figsize=(24, 4))
sns.set(font_scale=1.5)

ax = sns.barplot(x="Scenario", y="Average Goal Difference", hue='Evaluation Script', data=df[df["Scenario Type"]=="Defense"])

from matplotlib.ticker import MultipleLocator
ax.yaxis.set_major_locator(MultipleLocator(0.2))
ax.set(ylim=(-1, 0))
ax.set_xticklabels(['\n'.join(textwrap.wrap(ticklabel.get_text(),8)) for ticklabel in ax.get_xticklabels()])
ax.set(xlabel=None)
pyplot.legend(loc='lower left')
ax.figure.savefig("testing_defense_with_random.png", bbox_inches="tight")
