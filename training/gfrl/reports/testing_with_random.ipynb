# %%
import seaborn as sns

# %%
import pandas as pd

df = pd.read_csv("testing_with_random.csv")

# %%
df
# Out:
#     Scenario Type                                    Scenario  \
# 0         Academy                                  Empty Goal
# 1         Academy                                  Empty Goal
# 2         Academy                                  Empty Goal
# 3         Academy                                  Empty Goal
# 4         Academy                                  Empty Goal
# ..            ...                                         ...
# 130       Defense  Defender vs Opponent with Hesitant Dribble
# 131       Defense  Defender vs Opponent with Hesitant Dribble
# 132       Defense    Defender vs Opponent with Zigzag Dribble
# 133       Defense    Defender vs Opponent with Zigzag Dribble
# 134       Defense    Defender vs Opponent with Zigzag Dribble
#
#     Evaluation Script  Average Goal Difference
# 0            Training                     0.95
# 1            Training                     0.93
# 2            Training                     0.92
# 3             Testing                     0.55
# 4             Testing                     0.57
# ..                ...                      ...
# 130     Random Policy                    -0.78
# 131     Random Policy                    -0.70
# 132     Random Policy                    -0.45
# 133     Random Policy                    -0.43
# 134     Random Policy                    -0.38
#
# [135 rows x 4 columns]

# %%
from matplotlib import pyplot
import textwrap

#sns.set_theme(style="whitegrid")
sns.set_style('white')
pyplot.figure(figsize=(24, 4))
sns.set(font_scale=1.5)

ax = sns.barplot(x="Scenario", y="Average Goal Difference", hue='Evaluation Script', data=df[df["Scenario Type"]=="Defense"])

from matplotlib.ticker import MultipleLocator
ax.yaxis.set_major_locator(MultipleLocator(0.2))
ax.set(ylim=(-1, 0))
ax.set_xticklabels(['\n'.join(textwrap.wrap(ticklabel.get_text(),8)) for ticklabel in ax.get_xticklabels()])
ax.set(xlabel=None)
pyplot.legend(loc='lower left')
ax.figure.savefig("testing_defense_with_random.png", bbox_inches="tight")
